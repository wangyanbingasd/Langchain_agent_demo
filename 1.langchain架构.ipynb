# %%
import langchain
import sys
import openai

print(langchain.__version__)
print(sys.version)
print(openai.__version__)
# Out:
# 1.3.1
# 3.10.20 | packaged by Anaconda, Inc. | (main, Mar 11 2026, 17:42:35) [MSC v.1942 64 bit (AMD64)]
# 2.37.0

# %%
# 1.直接调用大模型hello world
import dotenv
from langchain_openai import ChatOpenAI
import os

dotenv.load_dotenv()

base_url = os.getenv("BASE_URL")
model_name = os.getenv("MODEL_NAME")
api_key = os.getenv("API_KEY")


llm = ChatOpenAI(model=model_name,api_key=api_key,base_url=base_url)
response = llm.invoke("什么是大模型")
print(response)
# Out:
# content='“大模型”（Large Model）通常是指**人工智能领域中参数量巨大、经过海量数据训练的深度学习模型**。它是当前人工智能技术发展的核心驱动力之一。\n\n虽然这个词在广义上可以指代各种大型 AI 模型，但在日常语境中，人们提到“大模型”时，往往特指**大语言模型（LLM）**。\n\n以下是对大模型的详细解读：\n\n### 1. 核心定义\n*   **参数量巨大：** “大”主要体现在模型的参数量上。传统的机器学习模型可能只有几百万或几千万个参数，而大模型通常拥有**几十亿甚至万亿级**的参数（例如 GPT-3 有 1750 亿参数）。这些参数决定了模型对信息的记忆和表达能力。\n*   **基础模型（Foundation Model）：** 它们是在大规模、通用数据集上进行预训练的，具备通用的知识和理解能力。用户不需要从零开始训练，而是可以通过微调（Fine-tuning）或提示工程（Prompt Engineering）让模型适应特定任务。\n\n### 2. 主要类型\n除了大家最熟悉的大语言模型外，“大模型”其实涵盖了很多领域：\n*   **大语言模型 (LLM)：** 专注于文本处理。能写文章、写代码、回答问题、翻译语言等。\n    *   *代表产品：* OpenAI 的 GPT 系列、Google 的 PaLM/Bard、阿里的通义千问 (Qwen)、百度的文心一言、智谱的 GLM 等。\n*   **多模态大模型 (Multimodal)：** 不仅能处理文字，还能理解图片、音频和视频。\n    *   *例子：* DALL-E 3（生成图片）、Sora（生成视频）、Gemini（支持图文理解）。\n*   **行业垂直大模型：** 基于通用大模型，针对医疗、法律、金融、教育等特定行业进行深度优化。\n    *   *作用：* 提供更专业、准确的建议，比如医疗诊断辅助。\n\n### 3. 它能做什么？（核心能力）\n大模型不仅仅是数据库检索，它具备更强的**泛化能力和创造力**：\n*   **内容生成：** 写作、写诗、写脚本、创作邮件。\n*   **代码辅助：** 自动生成代码片段、检查 Bug、解释复杂逻辑。\n*   **逻辑推理：** 解决数学问题、规划旅行路线、分析复杂数据。\n*   **人机对话：** 提供自然流畅的客服助手体验，情感陪伴。\n*   **知识问答：** 基于全网训练数据，回答广泛的常识性问题。\n\n### 4. 工作原理简述\n大模型的学习过程通常分为两个阶段：\n1.  **预训练 (Pre-training)：** 就像让一个学生读遍图书馆里的所有书。模型通过分析海量的互联网文本（网页、书籍、百科等），学习语言的语法、常识、逻辑和知识规律。这一阶段主要为了获得“通用智能”。\n2.  **微调 (Fine-tuning)：** 让学生针对特定的科目（如法律、编程或中文语境）进行强化学习，使其更符合人类指令或特定业务需求。这通常包含人类反馈强化学习 (RLHF)，让模型的回答更“懂人话”且符合价值观。\n\n### 5. 为什么最近这么火？\n过去几年，大模型之所以成为热点，是因为取得了质的飞跃：\n*   **Scaling Laws（缩放定律）：** 发现只要数据够多、算力够强、模型够大，模型的能力就会线性或指数级增长。\n*   **通用性强：** 以前 AI 是专才（只会下围棋的 AlphaGo），现在大模型是通才（既能写代码又能画画）。\n*   **落地场景丰富：** 从个人助理到企业办公，大模型极大地提高了生产力。\n\n### 6. 存在的挑战与局限\n尽管强大，大模型并非完美：\n*   **幻觉 (Hallucination)：** 模型可能会一本正经地胡说八道，编造不存在的事实或数据。\n*   **数据安全与隐私：** 输入模型的内容可能被用于训练，存在隐私泄露风险。\n*   **算力成本高昂：** 训练和运行大模型需要昂贵的 GPU 集群和巨大的电力消耗。\n*   **偏见与合规：** 模型可能学习到训练数据中的性别、种族偏见，或者生成违规内容。\n\n### 总结\n简单来说，**大模型就是目前最强大的“数字大脑”**。它通过阅读和理解海量信息，学会了像人类一样处理语言和逻辑任务。它正在重塑软件形态（从 App 变为 Agent）、改变工作方式，并被视为通向**通用人工智能（AGI）**的关键一步。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 2110, 'prompt_tokens': 13, 'total_tokens': 2123, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 1117, 'rejected_prediction_tokens': None, 'text_tokens': 2110}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': None, 'text_tokens': 13}}, 'model_provider': 'openai', 'model_name': 'qwen3.5-flash', 'system_fingerprint': None, 'id': 'chatcmpl-fb598af5-93c4-9a05-a080-eba236671a13', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e4b46-8905-7671-a7e5-46c0045094f8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 2110, 'total_tokens': 2123, 'input_token_details': {}, 'output_token_details': {'reasoning': 1117}}

# %%
# 2. 使用提示词模板
from langchain_core.prompts import ChatPromptTemplate

# from_messages 创建模板；format_messages 是实例方法，用于填入变量后生成消息列表
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "你无敌的大模型"),
        ("user", "{input}"),
    ]
)

chain = prompt | llm
message = chain.invoke({"input": "大模型中Langchain是什么呢"})
print(message)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 4
#       1 # 2. 使用提示词模板
#       2 from langchain_core.prompts import ChatPromptTemplate
# ----> 4 prompt = ChatPromptTemplate.format_messages(
#       5     [
#       6         ("system","你无敌的大模型"),
#       7         ("user","{input}")
#       8     ]
#       9 )
#      11 chain = prompt | llm
#      12 message = chain.invoker({"input":"大模型中Langchain是什么呢"})
#
# File d:\miniconda\envs\langchain_learn\lib\site-packages\langchain_core\prompts\chat.py:1183, in ChatPromptTemplate.format_messages(self, **kwargs)
#    1170 def format_messages(self, **kwargs: Any) -> list[BaseMessage]:
#    1171     """Format the chat template into a list of finalized messages.
#    1172
#    1173     Args:
#    (...)
#    1181         List of formatted messages.
#    1182     """
# -> 1183     kwargs = self._merge_partial_and_user_variables(**kwargs)
#    1184     result = []
#    1185     for message_template in self.messages:
#
# AttributeError: 'list' object has no attribute '_merge_partial_and_user_variables'
